# %% [markdown]
# ## Interacting with PostgreSQL
# For this demo, we'll load the dataset into my local PostgreSQL database.

# %%
import seaborn as sns
import pandas as pd

# %%
import seaborn as sns
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
import pandas as pd

# Replace 'your_dataset.csv' with the path to your dataset file
data = pd.read_csv('telco.csv')
print(data.head())
# Out:
#   Customer ID  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV    Male   78       No            Yes      No         No
# 1  7495-OOKFY  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents        Country       State  ...  \
# 0                     0  United States  California  ...
# 1                     1  United States  California  ...
# 2                     3  United States  California  ...
# 3                     1  United States  California  ...
# 4                     1  United States  California  ...
#
#   Total Extra Data Charges  Total Long Distance Charges  Total Revenue  \
# 0                       20                         0.00          59.65
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 50 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Under 30                           7043 non-null   object
#  4   Senior Citizen                     7043 non-null   object
#  5   Married                            7043 non-null   object
#  6   Dependents                         7043 non-null   object
#  7   Number of Dependents               7043 non-null   int64
#  8   Country                            7043 non-null   object
#  9   State                              7043 non-null   object
#  10  City                               7043 non-null   object
# ...

# %%
data.describe(include = 'all')
# Out:
#        Customer ID Gender          Age Under 30 Senior Citizen Married  \
# count         7043   7043  7043.000000     7043           7043    7043
# unique        7043      2          NaN        2              2       2
# top     8779-QRDMV   Male          NaN       No             No      No
# freq             1   3555          NaN     5642           5901    3641
# mean           NaN    NaN    46.509726      NaN            NaN     NaN
# std            NaN    NaN    16.750352      NaN            NaN     NaN
# min            NaN    NaN    19.000000      NaN            NaN     NaN
# 25%            NaN    NaN    32.000000      NaN            NaN     NaN
# 50%            NaN    NaN    46.000000      NaN            NaN     NaN
# 75%            NaN    NaN    60.000000      NaN            NaN     NaN
# max            NaN    NaN    80.000000      NaN            NaN     NaN
#
#        Dependents  Number of Dependents        Country       State  ...  \
# ...

# %%
data.head(10)
# Out:
#   Customer ID  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV    Male   78       No            Yes      No         No
# 1  7495-OOKFY  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ  Female   80       No            Yes     Yes        Yes
# 5  4412-YLTKF  Female   72       No            Yes      No        Yes
# 6  0390-DCFDQ  Female   76       No            Yes     Yes        Yes
# 7  3445-HXXGF    Male   66       No            Yes     Yes         No
# 8  2656-FMOKZ  Female   70       No            Yes      No        Yes
# 9  2070-FNEXE  Female   77       No            Yes      No        Yes
#
#    Number of Dependents        Country       State  ...  \
# 0                     0  United States  California  ...
# 1                     1  United States  California  ...
# ...

# %% [markdown]
# ### Creating a new database and schema

# %% [markdown]
# To create a new database, click on the Object drop-down, select Create and select database.

# %% [markdown]
# Enter the name of your new database and click Save.

# %%
data.shape
# Out:
# (7043, 50)

# %%
#!pip install psycopg2

# %%
from sqlalchemy import create_engine

# %%
# Note:: The make sure you use the information from your specific PostgreSQL installation
host = r'127.0.0.1' # denotes that the db in a local installation
db = r'MSDS610' # db we just created
user = r'system' # using the postgres user for this demo
pw = r'system123' # this is the password established during installation
port = r'5050' # default port estabalished during install
schema = r'raw' # schema we just created

# %%
db_conn = create_engine("postgresql://{}:{}@{}:{}/{}".format(user, pw, host, port, db))

# %%
sql="select tables.table_name from information_schema.tables where (table_schema ='"+schema+"')order by 1;"

# %%
table_name = r'telco'

# %%
tbl_df = pd.read_sql(sql, db_conn, index_col=None)
tbl_df

# %% [markdown]
# ### Retrieving data

# %%
sql = f"SELECT table_name FROM information_schema.tables WHERE table_schema = '{schema}' ORDER BY 1;"
tables = pd.read_sql(sql, db_conn)
telco_check = pd.read_sql(sql, db_conn, index_col=None)
# Display the DataFrame
print(telco.head())

# %%
telco_check.head(10)

# %% [markdown]
# ### Verified through pgAdmin
# In pgAdmin, right-click on the MSDS610 database and select Refresh.
# After the database refreshes, you should see the penguin_data table.
